# %%
x=5

# %%
# %timeit y=x**2
# Out:
# 42.7 ns ± 0.752 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit y=x*x
# Out:
# 34.2 ns ± 7.2 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
import numpy as np
z=np.uint8([5])

# %%
# %timeit y=z*z
# Out:
# 610 ns ± 55.7 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit y=np.square(z)
# Out:
# 520 ns ± 14.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
